# %%
import pandas as pd  # importing required libraries
import seaborn as sns

# %%
df = pd.read_excel("housing.xlsx")  # getting data from excel file

df      # viewing the dataframe
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.info()  # to get an idea about  the data type of each column , number of rows and columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
df["median_income"].mean()   # finding mean
# Out:
# 3.8706710029069766

# %%
sns.histplot(x= "median_income",data =df)  # creating histogram for median_income column
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %% [markdown]
# 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
sns.histplot(x= "housing_median_age",data =df)   # creating histogram for housing_median_age column
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
sns.lmplot(x="median_house_value" ,y="median_income",  data=df, fit_reg = False  )   # creating scatter plot

# %% [markdown]
# 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
df.info() # to get idea about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
bdrms = df[df["total_bedrooms"].notna()]  # notna() to find non - null rows
bdrms                                     # viewing the dataframe
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
x = df["total_bedrooms"].mean()   # calculating mean for total_bedrooms column
x
# Out:
# 537.8705525375618

# %%
df["total_bedrooms"].fillna(x, inplace = True) # replacing null values with mean

# %%
newdf = df[df["total_bedrooms"] == 537.8705525375618] # storing the data frame with mean values
newdf
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256      537.870553
# 341      -122.17     37.75                  38          992      537.870553
# 538      -122.28     37.78                  29         5154      537.870553
# 563      -122.24     37.75                  45          891      537.870553
# 696      -122.10     37.69                  41          746      537.870553
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620      537.870553
# 20268    -119.18     34.19                  19         2393      537.870553
# 20372    -118.88     34.17                  15         4260      537.870553
# 20460    -118.75     34.29                  17         5512      537.870553
# 20484    -118.72     34.28                  17         3051      537.870553
#
# ...

# %% [markdown]
# 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
def fmedian(x,y) :                  # defining a function with two parameters
  values  = x[y]                    # first extracting column from dataframe
  ans = values.median()             # finding median
  return ans

# %%
fmedian(df,'latitude') # calling the function and passing required arguments
# Out:
# 34.26

# %%
df['latitude'].median()
# Out:
# 34.26

# %% [markdown]
# 7. Plot latitude versus longitude and explain your observations.

# %%
sns.lmplot(x="latitude", y="longitude", data=df, fit_reg = False )   # creating a scatter plot

# %% [markdown]
# 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
df["ocean_proximity"].value_counts()   # to know the counts for each unique value in ocean_proximity column
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
Near_ocean = df[df["ocean_proximity"]== "NEAR OCEAN"]   # filtering the column for NEAR OCEAN proximity
Near_ocean.reset_index()                                # resetting the index of new dataframe
# Out:
#       index  longitude  latitude  housing_median_age  total_rooms  \
# 0      1850    -124.17     41.80                  16         2739
# 1      1851    -124.30     41.80                  19         2672
# 2      1852    -124.23     41.75                  11         3159
# 3      1853    -124.21     41.77                  17         3461
# 4      1854    -124.19     41.78                  15         3140
# ...     ...        ...       ...                 ...          ...
# 2653  20380    -118.83     34.14                  16         1316
# 2654  20381    -118.83     34.14                  16         1956
# 2655  20423    -119.00     34.08                  17         1822
# 2656  20424    -118.75     34.18                   4        16704
# 2657  20425    -118.75     34.17                  18         6217
#
#       total_bedrooms  population  households  median_income  \
# 0              480.0        1259         436         3.7557
# ...

# %% [markdown]
# 9. Find the mean and median of the median income for the data set created in question 8.

# %%
Near_ocean["median_income"].mean()   # calculating mean
# Out:
# 4.0057848006019565

# %%
Near_ocean["median_income"].median()   # calculating median
# Out:
# 3.64705

# %% [markdown]
# 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
def size(total_bedrooms) :               # defining a function with one parameter
  if total_bedrooms <= 10 :
    return 'small'
  elif total_bedrooms >10 and total_bedrooms <= 1000 :
    return 'medium'
  else :
    return 'large'

# %%
df['total_bedroom_size'] = df['total_bedrooms'].apply(size)   # creating a new column in the dataset

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
